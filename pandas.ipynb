# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame()

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1 = pd.DataFrame([[1,2,3,4],[5,6,7,8],[2,7,3,23],[3,6,8,23],[23,23,63,12]],columns=['A1','B1','C1','D1']) # create a data table

# %%
df1.head(3) # for showing upper 3 rows
# Out:
#    A1  B1  C1  D1
# 0   1   2   3   4
# 1   5   6   7   8
# 2   2   7   3  23

# %%
df1.tail(4) # for showing lower 3 rows
# Out:
#    A1  B1  C1  D1
# 1   5   6   7   8
# 2   2   7   3  23
# 3   3   6   8  23
# 4  23  23  63  12

# %%
df1.shape # for showing shape
# Out:
# (5, 4)

# %%
df1.iloc[0,1] # for slicing
# Out:
# 2

# %%
df1.iloc[0:2,0:2]
# Out:
#    A1  B1
# 0   1   2
# 1   5   6

# %%
df1.iloc[0:3,0:3]
# Out:
#    A1  B1  C1
# 0   1   2   3
# 1   5   6   7
# 2   2   7   3

# %%
df1.iloc[[0,3],[1,2]]
# Out:
#    B1  C1
# 0   2   3
# 3   6   8

# %%
df = pd.read_csv('customer.csv') # for uploading file
print(df)
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
print(df['CustomerID'].dtype) # for checking data type
# Out:
# int64

# %%
 df
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# 5             6  Female   22                  17                      76
# 6             7  Female   35                  18                       6
# 7             8  Female   23                  18                      94
# 8             9    Male   64                  19                       3
# 9            10  Female   30                  19                      72
# 10           11    Male   67                  19                      14
# 11           12  Female   35                  19                      99
# ...

# %%
df1
# Out:
#    A1  B1  C1  D1
# 0   1   2   3   4
# 1   5   6   7   8
# 2   2   7   3  23
# 3   3   6   8  23
# 4  23  23  63  12

# %%
df1.to_csv('export.csv') #writing a csv file

# %%
df2 = pd.DataFrame([[11,12,312],[22,7,35],[63,32,92]], columns=['x','y','z'])
df2
# Out:
#     x   y    z
# 0  11  12  312
# 1  22   7   35
# 2  63  32   92

# %%
df3 = pd.merge(df1,df2)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# <ipython-input-56-ff0427c2347d> in <module>()
# ----> 1 df3 = pd.merge(df1,df2)
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      45                          right_index=right_index, sort=sort, suffixes=suffixes,
#      46                          copy=copy, indicator=indicator,
# ---> 47                          validate=validate)
#      48     return op.get_result()
#      49
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/reshape/merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     522             warnings.warn(msg, UserWarning)
#     523
# ...
